# %% [markdown]
# # IMPORTS

# %%
import sys
sys.path.append('/content/drive/MyDrive/Romanian-Sign-Language-Image-Classification/utils_fn')

# %%
from tensorflow import keras
from keras import layers, models, utils
import numpy as np
from pathlib import Path
from generate_dataset import *
from plot_history import *
from generate_classification_report import *
from plot_confusion_matrix import *
from predict_image import *

utils.set_random_seed(42)

# %% [markdown]
# # CONSTANTS

# %%
SAVE_NAME = f'Model with augmentation and dropout'
DATASET_DIR = Path("/content/drive/MyDrive/Romanian-Sign-Language-Image-Classification/Ro_Sign_language_Dataset")
MODEL_SAVE_DIR = Path("/content/drive/MyDrive/Romanian-Sign-Language-Image-Classification/Saves")

BATCH_SIZE = 64
IMAGE_SIZE = (128, 128)
EPOCHS = 50

# %% [markdown]
# # PREPROCESSING

# %%
train_dataset, validation_dataset, test_dataset = generate_dataset(base_dir=DATASET_DIR, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE)
# Out:
# Found 15600 files belonging to 26 classes.
# Found 5200 files belonging to 26 classes.
# Found 5200 files belonging to 26 classes.

# %%
data_augmentation = keras.Sequential([layers.RandomFlip("horizontal"),
                                      layers.RandomRotation(0.05),
                                      layers.RandomZoom(0.2)])

rescale = layers.Rescaling(1./255)

# %% [markdown]
# # TRAINING

# %% [markdown]
# ## ARCHITECTURE

# %%
inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
x = data_augmentation(inputs)
x = rescale(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu')(x)
outputs = layers.Dense(26, activation="softmax")(x)
aug_drop_model = keras.Model(inputs=inputs, outputs=outputs)

aug_drop_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 126, 126, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 63, 63, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 256)       295168
#
#  max_pooling2d_7 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dropout_1 (Dropout)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 256)               2359552
#
#  dense_3 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 2754650 (10.51 MB)
# Trainable params: 2754650 (10.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
aug_drop_model.compile(loss="categorical_crossentropy",
                       optimizer="adam",
                       metrics=["accuracy"])

# %%
callbacks = [keras.callbacks.ModelCheckpoint(filepath = str(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}.model.keras'),
                                             save_best_only=True,
                                             monitor="val_loss")]

history = aug_drop_model.fit(train_dataset,
                       epochs=EPOCHS,
                       validation_data=validation_dataset,
                       callbacks=callbacks)

np.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}.history.npy', history.history)
bare_model.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}.model.h5', save_format='h5')
# Out:
# Epoch 1/50
# 244/244 [==============================] - 31s 115ms/step - loss: 2.7634 - accuracy: 0.1822 - val_loss: 2.0995 - val_accuracy: 0.3677
# Epoch 2/50
# 244/244 [==============================] - 28s 111ms/step - loss: 1.0858 - accuracy: 0.6609 - val_loss: 0.9255 - val_accuracy: 0.7019
# Epoch 3/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.5048 - accuracy: 0.8368 - val_loss: 0.9994 - val_accuracy: 0.7313
# Epoch 4/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.3138 - accuracy: 0.8972 - val_loss: 0.5624 - val_accuracy: 0.8473
# Epoch 5/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.2303 - accuracy: 0.9292 - val_loss: 0.4814 - val_accuracy: 0.8538
# Epoch 6/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.1756 - accuracy: 0.9426 - val_loss: 0.4679 - val_accuracy: 0.8571
# Epoch 7/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.1499 - accuracy: 0.9502 - val_loss: 0.3764 - val_accuracy: 0.8802
# Epoch 8/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.1255 - accuracy: 0.9600 - val_loss: 0.4385 - val_accuracy: 0.8783
# Epoch 9/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.1154 - accuracy: 0.9617 - val_loss: 0.2898 - val_accuracy: 0.9069
# Epoch 10/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.1040 - accuracy: 0.9663 - val_loss: 0.4281 - val_accuracy: 0.8827
# Epoch 11/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0910 - accuracy: 0.9703 - val_loss: 0.3854 - val_accuracy: 0.8981
# Epoch 12/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.0828 - accuracy: 0.9728 - val_loss: 0.3819 - val_accuracy: 0.9054
# Epoch 13/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.0690 - accuracy: 0.9777 - val_loss: 0.3448 - val_accuracy: 0.9112
# Epoch 14/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.0674 - accuracy: 0.9777 - val_loss: 0.2456 - val_accuracy: 0.9202
# Epoch 15/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0738 - accuracy: 0.9767 - val_loss: 0.2829 - val_accuracy: 0.9196
# Epoch 16/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0663 - accuracy: 0.9786 - val_loss: 0.3446 - val_accuracy: 0.9198
# Epoch 17/50
# 244/244 [==============================] - 27s 108ms/step - loss: 0.0608 - accuracy: 0.9806 - val_loss: 0.3690 - val_accuracy: 0.9029
# Epoch 18/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.0574 - accuracy: 0.9823 - val_loss: 0.4300 - val_accuracy: 0.8954
# Epoch 19/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0531 - accuracy: 0.9834 - val_loss: 0.4356 - val_accuracy: 0.8938
# Epoch 20/50
# 244/244 [==============================] - 27s 107ms/step - loss: 0.0641 - accuracy: 0.9801 - val_loss: 0.2872 - val_accuracy: 0.9192
# Epoch 21/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.0594 - accuracy: 0.9803 - val_loss: 0.2453 - val_accuracy: 0.9338
# Epoch 22/50
# 244/244 [==============================] - 27s 108ms/step - loss: 0.0467 - accuracy: 0.9849 - val_loss: 0.4021 - val_accuracy: 0.9177
# Epoch 23/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0459 - accuracy: 0.9860 - val_loss: 0.3470 - val_accuracy: 0.9188
# Epoch 24/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.0539 - accuracy: 0.9846 - val_loss: 0.2678 - val_accuracy: 0.9344
# Epoch 25/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0411 - accuracy: 0.9867 - val_loss: 0.2825 - val_accuracy: 0.9254
# Epoch 26/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0433 - accuracy: 0.9867 - val_loss: 0.3295 - val_accuracy: 0.9102
# Epoch 27/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0445 - accuracy: 0.9850 - val_loss: 0.4065 - val_accuracy: 0.9129
# Epoch 28/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 0.2660 - val_accuracy: 0.9404
# Epoch 29/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0317 - accuracy: 0.9894 - val_loss: 0.2935 - val_accuracy: 0.9187
# Epoch 30/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.0504 - accuracy: 0.9847 - val_loss: 0.1924 - val_accuracy: 0.9454
# Epoch 31/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0362 - accuracy: 0.9874 - val_loss: 0.2899 - val_accuracy: 0.9300
# Epoch 32/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.2790 - val_accuracy: 0.9431
# Epoch 33/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.3367 - val_accuracy: 0.9206
# Epoch 34/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.0376 - accuracy: 0.9882 - val_loss: 0.2251 - val_accuracy: 0.9406
# Epoch 35/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.2632 - val_accuracy: 0.9398
# Epoch 36/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.0393 - accuracy: 0.9890 - val_loss: 0.1463 - val_accuracy: 0.9606
# Epoch 37/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.0373 - accuracy: 0.9886 - val_loss: 0.2381 - val_accuracy: 0.9406
# Epoch 38/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.0291 - accuracy: 0.9902 - val_loss: 0.1864 - val_accuracy: 0.9548
# Epoch 39/50
# 244/244 [==============================] - 27s 110ms/step - loss: 0.0277 - accuracy: 0.9903 - val_loss: 0.3773 - val_accuracy: 0.9106
# Epoch 40/50
# 244/244 [==============================] - 27s 108ms/step - loss: 0.0389 - accuracy: 0.9890 - val_loss: 0.2559 - val_accuracy: 0.9392
# Epoch 41/50
# 244/244 [==============================] - 27s 108ms/step - loss: 0.0317 - accuracy: 0.9901 - val_loss: 0.1637 - val_accuracy: 0.9638
# Epoch 42/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0271 - accuracy: 0.9914 - val_loss: 0.2212 - val_accuracy: 0.9412
# Epoch 43/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0259 - accuracy: 0.9917 - val_loss: 0.1944 - val_accuracy: 0.9442
# Epoch 44/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0267 - accuracy: 0.9920 - val_loss: 0.5853 - val_accuracy: 0.8927
# Epoch 45/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.3221 - val_accuracy: 0.9312
# Epoch 46/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.0379 - accuracy: 0.9880 - val_loss: 0.1620 - val_accuracy: 0.9556
# Epoch 47/50
# 244/244 [==============================] - 28s 110ms/step - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.3037 - val_accuracy: 0.9242
# Epoch 48/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.0287 - accuracy: 0.9908 - val_loss: 0.1707 - val_accuracy: 0.9573
# Epoch 49/50
# 244/244 [==============================] - 27s 108ms/step - loss: 0.0226 - accuracy: 0.9915 - val_loss: 0.3320 - val_accuracy: 0.9277
# Epoch 50/50
# 244/244 [==============================] - 27s 109ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.1116 - val_accuracy: 0.9700
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history = np.load(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}.history.npy', allow_pickle=True).item()

plot_history(history)

# %% [markdown]
# ## EVALUATION

# %%
aug_drop_model = keras.models.load_model(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}.model.keras')
test_loss, test_acc = aug_drop_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 82/82 [==============================] - 16s 186ms/step - loss: 1.4208 - accuracy: 0.8567
# Test accuracy: 0.857

# %%
generate_classification_report(aug_drop_model, test_dataset)
# Out:
# 82/82 [==============================] - 15s 177ms/step
#               precision    recall  f1-score   support
#
#            A       0.45      0.99      0.62       200
#           Â       0.92      1.00      0.96       200
#           Ă       1.00      0.98      0.99       200
#            B       1.00      1.00      1.00       200
#            C       0.98      1.00      0.99       200
#            D       0.97      0.88      0.92       200
#            E       0.98      0.80      0.88       200
#            F       0.95      0.93      0.94       200
#            G       0.99      0.98      0.99       200
#            H       0.99      0.94      0.96       200
#            I       0.96      0.93      0.94       200
#            K       0.90      0.98      0.94       200
#            L       0.98      1.00      0.99       200
#            M       0.54      1.00      0.70       200
#            N       1.00      0.12      0.21       200
#            O       0.95      1.00      0.97       200
#            P       0.94      0.81      0.87       200
#            Q       0.99      0.89      0.94       200
#            R       1.00      0.10      0.17       200
#            S       0.57      0.07      0.12       200
#            T       0.96      0.94      0.95       200
#            U       0.54      0.98      0.70       200
#            V       1.00      1.00      1.00       200
#            W       1.00      1.00      1.00       200
#            X       0.84      0.99      0.91       200
#            Y       0.95      0.98      0.97       200
#
#     accuracy                           0.86      5200
#    macro avg       0.90      0.86      0.83      5200
# weighted avg       0.90      0.86      0.83      5200

# %%
plot_confusion_matrix(aug_drop_model, test_dataset)
# Out:
# 82/82 [==============================] - 20s 238ms/step
