# %% [markdown]
# # IMPORTS

# %%
import sys
sys.path.append('/content/drive/MyDrive/Romanian-Sign-Language-Image-Classification/utils_fn')

# %%
from tensorflow import keras
from keras import layers, models, utils, regularizers
import numpy as np
from pathlib import Path
from generate_dataset import *
from plot_history import *
from generate_classification_report import *
from plot_confusion_matrix import *
from predict_image import *

utils.set_random_seed(42)

# %% [markdown]
# # CONSTANTS

# %%
SAVE_NAME = f'Model with augmentation and dropout and regularization'
DATASET_DIR = Path("/content/drive/MyDrive/Romanian-Sign-Language-Image-Classification/Ro_Sign_language_Dataset")
MODEL_SAVE_DIR = Path("/content/drive/MyDrive/Romanian-Sign-Language-Image-Classification/Saves")

BATCH_SIZE = 64
IMAGE_SIZE = (128, 128)
EPOCHS = 50

# %% [markdown]
# # PREPROCESSING

# %%
train_dataset, validation_dataset, test_dataset = generate_dataset(base_dir=DATASET_DIR, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE)
# Out:
# Found 15600 files belonging to 26 classes.
# Found 5200 files belonging to 26 classes.
# Found 5200 files belonging to 26 classes.

# %%
data_augmentation = keras.Sequential([layers.RandomFlip("horizontal"),
                                      layers.RandomRotation(0.05),
                                      layers.RandomZoom(0.2)])

rescale = layers.Rescaling(1./255)

# %% [markdown]
# # 64

# %% [markdown]
# ## ARCHITECTURE

# %%
inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
x = data_augmentation(inputs)
x = rescale(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.L2())(x)
outputs = layers.Dense(26, activation="softmax")(x)
aug_drop_reg_64_model = keras.Model(inputs=inputs, outputs=outputs)

aug_drop_reg_64_model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 128, 128, 3)]     0
#
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d_36 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_36 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_37 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_38 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_39 (MaxPooli  (None, 6, 6, 256)         0
#  ng2D)
#
#  flatten_9 (Flatten)         (None, 9216)              0
#
#  dropout_9 (Dropout)         (None, 9216)              0
#
#  dense_18 (Dense)            (None, 64)                589888
#
#  dense_19 (Dense)            (None, 26)                1690
#
# =================================================================
# Total params: 979994 (3.74 MB)
# Trainable params: 979994 (3.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
aug_drop_reg_64_model.compile(loss="categorical_crossentropy",
                              optimizer="adam",
                              metrics=["accuracy"])

# %%
callbacks = [keras.callbacks.ModelCheckpoint(filepath = str(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}64.model.keras'),
                                             save_best_only=True,
                                             monitor="val_loss")]

history = aug_drop_reg_64_model.fit(train_dataset,
                       epochs=EPOCHS,
                       validation_data=validation_dataset,
                       callbacks=callbacks)

np.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}64.history.npy', history.history)
aug_drop_reg_64_model.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}64.model.h5', save_format='h5')
# Out:
# Epoch 1/50
# 244/244 [==============================] - 33s 123ms/step - loss: 3.2242 - accuracy: 0.0844 - val_loss: 3.2880 - val_accuracy: 0.0763
# Epoch 2/50
# 244/244 [==============================] - 29s 115ms/step - loss: 2.5687 - accuracy: 0.2872 - val_loss: 2.3599 - val_accuracy: 0.3944
# Epoch 3/50
# 244/244 [==============================] - 28s 114ms/step - loss: 1.6864 - accuracy: 0.5726 - val_loss: 1.6697 - val_accuracy: 0.5983
# Epoch 4/50
# 244/244 [==============================] - 29s 115ms/step - loss: 1.2915 - accuracy: 0.6994 - val_loss: 1.3030 - val_accuracy: 0.7188
# Epoch 5/50
# 244/244 [==============================] - 29s 116ms/step - loss: 1.0807 - accuracy: 0.7611 - val_loss: 1.1295 - val_accuracy: 0.7521
# Epoch 6/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0
50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3846 - accuracy: 0.9536 - val_loss: 0.5632 - val_accuracy: 0.8950
# Epoch 32/50
# 244/244 [==============================] - 30s 118ms/step - loss: 0.4043 - accuracy: 0.9508 - val_loss: 0.5826 - val_accuracy: 0.9010
# Epoch 33/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.3814 - accuracy: 0.9553 - val_loss: 0.4847 - val_accuracy: 0.9175
# Epoch 34/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.3821 - accuracy: 0.9523 - val_loss: 0.5190 - val_accuracy: 0.9171
# Epoch 35/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.3777 - accuracy: 0.9546 - val_loss: 0.6278 - val_accuracy: 0.8848
# Epoch 36/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3866 - accuracy: 0.9560 - val_loss: 0.7044 - val_accuracy: 0.8519
# Epoch 37/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3650 - accuracy: 0.9581 - val_loss: 0.6145 - val_accuracy: 0.8840
# Epoch 38/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3583 - accuracy: 0.9606 - val_loss: 0.6299 - val_accuracy: 0.8790
# Epoch 39/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3259 - accuracy: 0.9644 - val_loss: 0.5103 - val_accuracy: 0.9021
# Epoch 40/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.3514 - accuracy: 0.9602 - val_loss: 0.5308 - val_accuracy: 0.9033
# Epoch 41/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3369 - accuracy: 0.9637 - val_loss: 0.4789 - val_accuracy: 0.9092
# Epoch 42/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3283 - accuracy: 0.9631 - val_loss: 0.6364 - val_accuracy: 0.8710
# Epoch 43/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.3250 - accuracy: 0.9640 - val_loss: 0.6251 - val_accuracy: 0.8760
# Epoch 44/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.3314 - accuracy: 0.9618 - val_loss: 0.6204 - val_accuracy: 0.8704
# Epoch 45/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.3314 - accuracy: 0.9632 - val_loss: 0.5330 - val_accuracy: 0.9065
# Epoch 46/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.3110 - accuracy: 0.9692 - val_loss: 0.6217 - val_accuracy: 0.8737
# Epoch 47/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.3313 - accuracy: 0.9630 - val_loss: 0.4383 - val_accuracy: 0.9300
# Epoch 48/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.3005 - accuracy: 0.9705 - val_loss: 0.4956 - val_accuracy: 0.9260
# Epoch 49/50
# 244/244 [==============================] - 29s 114ms/step - loss: 0.3307 - accuracy: 0.9624 - val_loss: 0.5206 - val_accuracy: 0.9096
# Epoch 50/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.3084 - accuracy: 0.9701 - val_loss: 0.7207 - val_accuracy: 0.8525
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history = np.load(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}64.history.npy', allow_pickle=True).item()

plot_history(history)

# %% [markdown]
# ## EVALUATION

# %%
aug_drop_reg_64_model = keras.models.load_model(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}64.model.keras')
test_loss, test_acc = aug_drop_reg_64_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 82/82 [==============================] - 143s 2s/step - loss: 1.4384 - accuracy: 0.8094
# Test accuracy: 0.809

# %%
generate_classification_report(aug_drop_reg_64_model, test_dataset)
# Out:
# 82/82 [==============================] - 14s 174ms/step
#               precision    recall  f1-score   support
#
#            A       0.67      0.95      0.78       200
#           Â       0.98      0.98      0.98       200
#           Ă       1.00      1.00      1.00       200
#            B       0.91      0.95      0.93       200
#            C       0.96      1.00      0.98       200
#            D       0.93      0.60      0.73       200
#            E       0.84      0.94      0.88       200
#            F       0.83      0.81      0.82       200
#            G       1.00      0.69      0.82       200
#            H       0.76      0.98      0.86       200
#            I       0.93      0.93      0.93       200
#            K       0.97      0.74      0.84       200
#            L       0.89      0.95      0.92       200
#            M       0.51      0.95      0.66       200
#            N       1.00      0.01      0.01       200
#            O       0.65      1.00      0.79       200
#            P       0.97      0.99      0.98       200
#            Q       1.00      0.85      0.92       200
#            R       0.11      0.04      0.06       200
#            S       0.65      0.07      0.12       200
#            T       0.92      0.82      0.87       200
#            U       0.47      0.99      0.64       200
#            V       1.00      0.92      0.96       200
#            W       0.92      1.00      0.96       200
#            X       0.83      0.93      0.88       200
#            Y       0.99      0.92      0.96       200
#
#     accuracy                           0.81      5200
#    macro avg       0.83      0.81      0.78      5200
# weighted avg       0.83      0.81      0.78      5200

# %%
plot_confusion_matrix(aug_drop_reg_64_model, test_dataset)
# Out:
# 82/82 [==============================] - 15s 187ms/step

# %% [markdown]
# # 128

# %% [markdown]
# ## ARCHITECTURE

# %%
inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
x = data_augmentation(inputs)
x = rescale(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.L2())(x)
outputs = layers.Dense(26, activation="softmax")(x)
aug_drop_reg_128_model = keras.Model(inputs=inputs, outputs=outputs)

aug_drop_reg_128_model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d_24 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_24 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_25 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_25 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_26 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_27 (MaxPooli  (None, 6, 6, 256)         0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 9216)              0
#
#  dropout_6 (Dropout)         (None, 9216)              0
#
#  dense_12 (Dense)            (None, 128)               1179776
#
#  dense_13 (Dense)            (None, 26)                3354
#
# =================================================================
# Total params: 1571546 (5.99 MB)
# Trainable params: 1571546 (5.99 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
aug_drop_reg_128_model.compile(loss="categorical_crossentropy",
                               optimizer="adam",
                               metrics=["accuracy"])

# %%
callbacks = [keras.callbacks.ModelCheckpoint(filepath = str(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}128.model.keras'),
                                             save_best_only=True,
                                             monitor="val_loss")]

history = aug_drop_reg_128_model.fit(train_dataset,
                       epochs=EPOCHS,
                       validation_data=validation_dataset,
                       callbacks=callbacks)

np.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}128.history.npy', history.history)
aug_drop_reg_128_model.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}128.model.h5', save_format='h5')
# Out:
# Epoch 1/50
# 122/122 [==============================] - 34s 251ms/step - loss: 3.3472 - accuracy: 0.0978 - val_loss: 3.4229 - val_accuracy: 0.1027
# Epoch 2/50
# 122/122 [==============================] - 29s 224ms/step - loss: 2.6564 - accuracy: 0.3030 - val_loss: 2.5474 - val_accuracy: 0.3938
# Epoch 3/50
# 122/122 [==============================] - 29s 224ms/step - loss: 1.8224 - accuracy: 0.5954 - val_loss: 1.9216 - val_accuracy: 0.6213
# Epoch 4/50
# 122/122 [==============================] - 29s 226ms/step - loss: 1.3940 - accuracy: 0.7279 - val_loss: 1.3346 - val_accuracy: 0.7567
# Epoch 5/50
# 122/122 [==============================] - 29s 230ms/step - loss: 1.1321 - accuracy: 0.8002 - val_loss: 1.0893 - val_accuracy: 0.8121
# Epoch 6/50
# 122/122 [==============================] - 29s 224ms/step - loss: 0.9898 - accuracy: 0.8393 - val_loss: 1.0695 - val_accuracy: 0.8094
# Epoch 7/50
# 122/122 [==============================] - 29s 225ms/step - loss: 0.9258 - accuracy: 0.8554 - val_loss: 1.1750 - val_accuracy: 0.8008
# Epoch 8/50
# 122/122 [==============================] - 29s 224ms/step - loss: 0
MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}128.history.npy', allow_pickle=True).item()

plot_history(history)

# %% [markdown]
# ## EVALUATION

# %%
aug_drop_reg_128_model = keras.models.load_model(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}128.model.keras')
test_loss, test_acc = aug_drop_reg_128_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 82/82 [==============================] - 15s 177ms/step - loss: 1.2623 - accuracy: 0.8421
# Test accuracy: 0.842

# %%
generate_classification_report(aug_drop_reg_128_model, test_dataset)
# Out:
# 82/82 [==============================] - 15s 179ms/step
#               precision    recall  f1-score   support
#
#            A       0.49      1.00      0.65       200
#           Â       0.96      0.98      0.97       200
#           Ă       0.99      0.92      0.95       200
#            B       0.99      0.93      0.96       200
#            C       0.88      1.00      0.93       200
#            D       0.86      0.97      0.92       200
#            E       1.00      0.63      0.77       200
#            F       0.81      0.83      0.82       200
#            G       0.99      0.79      0.88       200
#            H       0.85      0.91      0.88       200
#            I       0.94      0.86      0.90       200
#            K       0.91      0.69      0.79       200
#            L       0.82      0.97      0.89       200
#            M       0.53      1.00      0.69       200
#            N       0.95      0.10      0.19       200
#            O       0.80      1.00      0.89       200
#            P       0.90      0.97      0.93       200
#            Q       0.97      0.90      0.94       200
#            R       1.00      0.64      0.78       200
#            S       0.48      0.06      0.10       200
#            T       0.88      0.91      0.89       200
#            U       0.75      0.99      0.85       200
#            V       0.97      0.95      0.96       200
#            W       0.93      0.99      0.96       200
#            X       1.00      0.96      0.98       200
#            Y       0.90      0.94      0.92       200
#
#     accuracy                           0.84      5200
#    macro avg       0.87      0.84      0.82      5200
# weighted avg       0.87      0.84      0.82      5200

# %%
plot_confusion_matrix(aug_drop_reg_128_model, test_dataset)
# Out:
# 82/82 [==============================] - 14s 175ms/step

# %% [markdown]
# # 256

# %% [markdown]
# ## ARCHITECTURE

# %%
inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
x = data_augmentation(inputs)
x = rescale(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.L2())(x)
outputs = layers.Dense(26, activation="softmax")(x)
aug_drop_reg_256_model = keras.Model(inputs=inputs, outputs=outputs)

aug_drop_reg_256_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dropout (Dropout)           (None, 9216)              0
#
#  dense (Dense)               (None, 256)               2359552
#
#  dense_1 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 2754650 (10.51 MB)
# Trainable params: 2754650 (10.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
aug_drop_reg_256_model.compile(loss="categorical_crossentropy",
                               optimizer="adam",
                               metrics=["accuracy"])

# %%
callbacks = [keras.callbacks.ModelCheckpoint(filepath = str(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}256.model.keras'),
                                             save_best_only=True,
                                             monitor="val_loss")]

history = aug_drop_reg_256_model.fit(train_dataset,
                       epochs=EPOCHS,
                       validation_data=validation_dataset,
                       callbacks=callbacks)

np.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}256.history.npy', history.history)
aug_drop_reg_256_model.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}256.model.h5', save_format='h5')
# Out:
# Epoch 1/50
# 244/244 [==============================] - 36s 124ms/step - loss: 3.3594 - accuracy: 0.1138 - val_loss: 3.2299 - val_accuracy: 0.1865
# Epoch 2/50
# 244/244 [==============================] - 29s 115ms/step - loss: 2.2344 - accuracy: 0.4888 - val_loss: 1.9044 - val_accuracy: 0.6060
# Epoch 3/50
# 244/244 [==============================] - 28s 113ms/step - loss: 1.4882 - accuracy: 0.7217 - val_loss: 1.5396 - val_accuracy: 0.7054
# Epoch 4/50
# 244/244 [==============================] - 29s 115ms/step - loss: 1.2217 - accuracy: 0.7917 - val_loss: 1.2801 - val_accuracy: 0.7673
# Epoch 5/50
# 244/244 [==============================] - 29s 115ms/step - loss: 1.0738 - accuracy: 0.8228 - val_loss: 1.1265 - val_accuracy: 0.8173
# Epoch 6/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.9764 - accuracy: 0.8540 - val_loss: 1.0608 - val_accuracy: 0.8277
# Epoch 7/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.9190 - accuracy: 0.8699 - val_loss: 0.9975 - val_accuracy: 0.8444
# Epoch 8/50
# 244/244 [==============================] - 28s 114ms/step - loss: 0.8538 - accuracy: 0.8798 - val_loss: 0.8956 - val_accuracy: 0.8656
# Epoch 9/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.8015 - accuracy: 0.8970 - val_loss: 0.8304 - val_accuracy: 0.8800
# Epoch 10/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.7770 - accuracy: 0.9028 - val_loss: 0.7915 - val_accuracy: 0.8973
# Epoch 11/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.7429 - accuracy: 0.9137 - val_loss: 0.8044 - val_accuracy: 0.8827
# Epoch 12/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.7047 - accuracy: 0.9161 - val_loss: 0.7340 - val_accuracy: 0.8994
# Epoch 13/50
# 244/244 [==============================] - 28s 114ms/step - loss: 0.6954 - accuracy: 0.9174 - val_loss: 0.6281 - val_accuracy: 0.9387
# Epoch 14/50
# 244/244 [==============================] - 29s 114ms/step - loss: 0.6616 - accuracy: 0.9283 - val_loss: 0.7196 - val_accuracy: 0.9062
# Epoch 15/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.6564 - accuracy: 0.9253 - val_loss: 0.6884 - val_accuracy: 0.9208
# Epoch 16/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.6328 - accuracy: 0.9316 - val_loss: 0.6849 - val_accuracy: 0.9088
# Epoch 17/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.6324 - accuracy: 0.9320 - val_loss: 0.8229 - val_accuracy: 0.8860
# Epoch 18/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.6081 - accuracy: 0.9357 - val_loss: 0.7772 - val_accuracy: 0.8802
# Epoch 19/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.6086 - accuracy: 0.9349 - val_loss: 0.7181 - val_accuracy: 0.9213
# Epoch 20/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5770 - accuracy: 0.9426 - val_loss: 0.8470 - val_accuracy: 0.8502
# Epoch 21/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.5651 - accuracy: 0.9447 - val_loss: 0.6331 - val_accuracy: 0.9188
# Epoch 22/50
# 244/244 [==============================] - 28s 114ms/step - loss: 0.5694 - accuracy: 0.9424 - val_loss: 0.6978 - val_accuracy: 0.8948
# Epoch 23/50
# 244/244 [==============================] - 29s 114ms/step - loss: 0.5730 - accuracy: 0.9410 - val_loss: 0.5729 - val_accuracy: 0.9375
# Epoch 24/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.5280 - accuracy: 0.9474 - val_loss: 0.6403 - val_accuracy: 0.8975
# Epoch 25/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.5014 - accuracy: 0.9506 - val_loss: 0.5869 - val_accuracy: 0.9265
# Epoch 26/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5301 - accuracy: 0.9478 - val_loss: 0.6796 - val_accuracy: 0.9098
# Epoch 27/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4974 - accuracy: 0.9533 - val_loss: 0.5729 - val_accuracy: 0.9273
# Epoch 28/50
# 244/244 [==============================] - 28s 114ms/step - loss: 0.4971 - accuracy: 0.9529 - val_loss: 0.5085 - val_accuracy: 0.9440
# Epoch 29/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4690 - accuracy: 0.9576 - val_loss: 0.6282 - val_accuracy: 0.9013
# Epoch 30/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.4872 - accuracy: 0.9536 - val_loss: 0.6163 - val_accuracy: 0.9075
# Epoch 31/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4739 - accuracy: 0.9558 - val_loss: 0.5436 - val_accuracy: 0.9302
# Epoch 32/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4627 - accuracy: 0.9583 - val_loss: 0.5577 - val_accuracy: 0.9240
# Epoch 33/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4604 - accuracy: 0.9583 - val_loss: 0.5426 - val_accuracy: 0.9323
# Epoch 34/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4449 - accuracy: 0.9590 - val_loss: 0.5206 - val_accuracy: 0.9358
# Epoch 35/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4399 - accuracy: 0.9603 - val_loss: 0.4798 - val_accuracy: 0.9452
# Epoch 36/50
# 244/244 [==============================] - 28s 114ms/step - loss: 0.4335 - accuracy: 0.9595 - val_loss: 0.4544 - val_accuracy: 0.9558
# Epoch 37/50
# 244/244 [==============================] - 28s 114ms/step - loss: 0.4426 - accuracy: 0.9603 - val_loss: 0.4914 - val_accuracy: 0.9358
# Epoch 38/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4186 - accuracy: 0.9641 - val_loss: 0.4991 - val_accuracy: 0.9337
# Epoch 39/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.4240 - accuracy: 0.9612 - val_loss: 0.7153 - val_accuracy: 0.8990
# Epoch 40/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.4043 - accuracy: 0.9644 - val_loss: 0.5006 - val_accuracy: 0.9515
# Epoch 41/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.3973 - accuracy: 0.9663 - val_loss: 0.5074 - val_accuracy: 0.9225
# Epoch 42/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4176 - accuracy: 0.9640 - val_loss: 0.4640 - val_accuracy: 0.9381
# Epoch 43/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.3993 - accuracy: 0.9653 - val_loss: 0.4881 - val_accuracy: 0.9354
# Epoch 44/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4049 - accuracy: 0.9647 - val_loss: 0.4656 - val_accuracy: 0.9421
# Epoch 45/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.3988 - accuracy: 0.9659 - val_loss: 0.4602 - val_accuracy: 0.9456
# Epoch 46/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.3646 - accuracy: 0.9683 - val_loss: 0.4133 - val_accuracy: 0.9546
# Epoch 47/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.3568 - accuracy: 0.9691 - val_loss: 0.5103 - val_accuracy: 0.9263
# Epoch 48/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.3617 - accuracy: 0.9690 - val_loss: 0.4817 - val_accuracy: 0.9344
# Epoch 49/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.3743 - accuracy: 0.9656 - val_loss: 0.4430 - val_accuracy: 0.9423
# Epoch 50/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.3611 - accuracy: 0.9708 - val_loss: 0.4456 - val_accuracy: 0.9338
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history = np.load(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}256.history.npy', allow_pickle=True).item()

plot_history(history)

# %% [markdown]
# ## EVALUATION

# %%
aug_drop_reg_256_model = keras.models.load_model(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}256.model.keras')
test_loss, test_acc = aug_drop_reg_256_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 82/82 [==============================] - 15s 177ms/step - loss: 1.2513 - accuracy: 0.8346
# Test accuracy: 0.835

# %%
generate_classification_report(aug_drop_reg_256_model, test_dataset)
# Out:
# 82/82 [==============================] - 14s 167ms/step
#               precision    recall  f1-score   support
#
#            A       0.66      0.97      0.79       200
#           Â       0.93      1.00      0.96       200
#           Ă       0.99      0.97      0.98       200
#            B       0.88      0.93      0.91       200
#            C       0.95      1.00      0.97       200
#            D       0.78      0.98      0.87       200
#            E       0.93      0.96      0.95       200
#            F       0.99      0.74      0.85       200
#            G       0.99      0.99      0.99       200
#            H       0.99      0.92      0.95       200
#            I       0.99      0.93      0.96       200
#            K       0.95      0.49      0.65       200
#            L       0.64      1.00      0.78       200
#            M       0.49      0.97      0.65       200
#            N       0.00      0.00      0.00       200
#            O       0.64      1.00      0.78       200
#            P       0.99      0.89      0.94       200
#            Q       0.99      0.94      0.97       200
#            R       0.99      0.34      0.51       200
#            S       0.83      0.07      0.14       200
#            T       0.84      0.71      0.77       200
#            U       0.59      0.94      0.73       200
#            V       0.99      0.97      0.98       200
#            W       0.96      1.00      0.98       200
#            X       0.96      0.96      0.96       200
#            Y       0.97      0.99      0.98       200
#
#     accuracy                           0.83      5200
#    macro avg       0.84      0.83      0.81      5200
# weighted avg       0.84      0.83      0.81      5200

# %%
plot_confusion_matrix(aug_drop_reg_256_model, test_dataset)
# Out:
# 82/82 [==============================] - 14s 170ms/step

# %% [markdown]
# # 512

# %% [markdown]
# ## ARCHITECTURE

# %%
inputs = keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
x = data_augmentation(inputs)
x = rescale(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.L2())(x)
outputs = layers.Dense(26, activation="softmax")(x)
aug_drop_reg_512_model = keras.Model(inputs=inputs, outputs=outputs)

aug_drop_reg_512_model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 128, 128, 3)]     0
#
#  sequential (Sequential)     (None, 128, 128, 3)       0
#
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d_40 (Conv2D)          (None, 126, 126, 32)      896
#
#  max_pooling2d_40 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_41 (Conv2D)          (None, 61, 61, 64)        18496
#
#  max_pooling2d_41 (MaxPooli  (None, 30, 30, 64)        0
#  ng2D)
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)       73856
#
#  max_pooling2d_42 (MaxPooli  (None, 14, 14, 128)       0
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 12, 12, 256)       295168
#
#  max_pooling2d_43 (MaxPooli  (None, 6, 6, 256)         0
#  ng2D)
#
#  flatten_10 (Flatten)        (None, 9216)              0
#
#  dropout_10 (Dropout)        (None, 9216)              0
#
#  dense_20 (Dense)            (None, 512)               4719104
#
#  dense_21 (Dense)            (None, 26)                13338
#
# =================================================================
# Total params: 5120858 (19.53 MB)
# Trainable params: 5120858 (19.53 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
aug_drop_reg_512_model.compile(loss="categorical_crossentropy",
                               optimizer="adam",
                               metrics=["accuracy"])

# %%
callbacks = [keras.callbacks.ModelCheckpoint(filepath = str(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}512.model.keras'),
                                             save_best_only=True,
                                             monitor="val_loss")]

history = aug_drop_reg_512_model.fit(train_dataset,
                       epochs=EPOCHS,
                       validation_data=validation_dataset,
                       callbacks=callbacks)

np.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}512.history.npy', history.history)
aug_drop_reg_512_model.save(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}512.model.h5', save_format='h5')
# Out:
# Epoch 1/50
# 244/244 [==============================] - 32s 119ms/step - loss: 3.5516 - accuracy: 0.0777 - val_loss: 3.4127 - val_accuracy: 0.0404
# Epoch 2/50
# 244/244 [==============================] - 29s 117ms/step - loss: 2.8044 - accuracy: 0.2583 - val_loss: 2.6597 - val_accuracy: 0.3106
# Epoch 3/50
# 244/244 [==============================] - 30s 117ms/step - loss: 1.9526 - accuracy: 0.5546 - val_loss: 2.0233 - val_accuracy: 0.5410
# Epoch 4/50
# 244/244 [==============================] - 29s 116ms/step - loss: 1.5261 - accuracy: 0.6858 - val_loss: 1.7281 - val_accuracy: 0.6306
# Epoch 5/50
# 244/244 [==============================] - 29s 118ms/step - loss: 1.3320 - accuracy: 0.7510 - val_loss: 1.6454 - val_accuracy: 0.6588
# Epoch 6/50
# 244/244 [==============================] - 29s 117ms/step - loss: 1.2069 - accuracy: 0.7876 - val_loss: 1.7550 - val_accuracy: 0.6500
# Epoch 7/50
# 244/244 [==============================] - 29s 117ms/step - loss: 1.0892 - accuracy: 0.8234 - val_loss: 1.5530 - val_accuracy: 0.6813
# Epoch 8/50
# 244/244 [==============================] - 30s 118ms/step - loss: 1.0413 - accuracy: 0.8377 - val_loss: 1.3571 - val_accuracy: 0.7550
# Epoch 9/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.9721 - accuracy: 0.8520 - val_loss: 1.1283 - val_accuracy: 0.8215
# Epoch 10/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.9076 - accuracy: 0.8640 - val_loss: 1.1245 - val_accuracy: 0.8104
# Epoch 11/50
# 244/244 [==============================] - 29s 117ms/step - loss: 0.8719 - accuracy: 0.8771 - val_loss: 0.9460 - val_accuracy: 0.8419
# Epoch 12/50
# 244/244 [==============================] - 29s 114ms/step - loss: 0.7916 - accuracy: 0.8878 - val_loss: 1.1798 - val_accuracy: 0.7887
# Epoch 13/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.7771 - accuracy: 0.8884 - val_loss: 0.9033 - val_accuracy: 0.8596
# Epoch 14/50
# 244/244 [==============================] - 29s 114ms/step - loss: 0.7469 - accuracy: 0.9016 - val_loss: 1.0509 - val_accuracy: 0.8090
# Epoch 15/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.7128 - accuracy: 0.9057 - val_loss: 1.0201 - val_accuracy: 0.8292
# Epoch 16/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.7165 - accuracy: 0.9095 - val_loss: 0.9598 - val_accuracy: 0.8387
# Epoch 17/50
# 244/244 [==============================] - 29s 115ms/step - loss: 0.6815 - accuracy: 0.9104 - val_loss: 0.8194 - val_accuracy: 0.8775
# Epoch 18/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.6572 - accuracy: 0.9180 - val_loss: 0.8237 - val_accuracy: 0.8758
# Epoch 19/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.6317 - accuracy: 0.9232 - val_loss: 0.8219 - val_accuracy: 0.8823
# Epoch 20/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.6436 - accuracy: 0.9208 - val_loss: 0.8649 - val_accuracy: 0.8448
# Epoch 21/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.6013 - accuracy: 0.9229 - val_loss: 0.7105 - val_accuracy: 0.8862
# Epoch 22/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.5815 - accuracy: 0.9317 - val_loss: 0.7008 - val_accuracy: 0.8817
# Epoch 23/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5791 - accuracy: 0.9294 - val_loss: 0.6654 - val_accuracy: 0.8973
# Epoch 24/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5834 - accuracy: 0.9283 - val_loss: 0.7059 - val_accuracy: 0.8929
# Epoch 25/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5535 - accuracy: 0.9337 - val_loss: 0.6858 - val_accuracy: 0.8869
# Epoch 26/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.5509 - accuracy: 0.9335 - val_loss: 0.6725 - val_accuracy: 0.9037
# Epoch 27/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5550 - accuracy: 0.9359 - val_loss: 0.6670 - val_accuracy: 0.8938
# Epoch 28/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5308 - accuracy: 0.9382 - val_loss: 0.6917 - val_accuracy: 0.8800
# Epoch 29/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.5215 - accuracy: 0.9402 - val_loss: 0.8259 - val_accuracy: 0.8398
# Epoch 30/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.5151 - accuracy: 0.9408 - val_loss: 0.5847 - val_accuracy: 0.9250
# Epoch 31/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.5031 - accuracy: 0.9459 - val_loss: 0.7181 - val_accuracy: 0.8900
# Epoch 32/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4816 - accuracy: 0.9440 - val_loss: 0.6022 - val_accuracy: 0.9065
# Epoch 33/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4781 - accuracy: 0.9468 - val_loss: 0.5869 - val_accuracy: 0.9112
# Epoch 34/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4905 - accuracy: 0.9442 - val_loss: 0.6355 - val_accuracy: 0.9015
# Epoch 35/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4628 - accuracy: 0.9502 - val_loss: 0.6004 - val_accuracy: 0.9069
# Epoch 36/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.4603 - accuracy: 0.9509 - val_loss: 0.6040 - val_accuracy: 0.9008
# Epoch 37/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4579 - accuracy: 0.9506 - val_loss: 0.6357 - val_accuracy: 0.8975
# Epoch 38/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4437 - accuracy: 0.9522 - val_loss: 0.5956 - val_accuracy: 0.9244
# Epoch 39/50
# 244/244 [==============================] - 29s 116ms/step - loss: 0.4671 - accuracy: 0.9478 - val_loss: 0.5786 - val_accuracy: 0.9127
# Epoch 40/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4290 - accuracy: 0.9537 - val_loss: 0.4950 - val_accuracy: 0.9319
# Epoch 41/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4272 - accuracy: 0.9549 - val_loss: 0.5241 - val_accuracy: 0.9258
# Epoch 42/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4278 - accuracy: 0.9538 - val_loss: 0.5661 - val_accuracy: 0.9073
# Epoch 43/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4198 - accuracy: 0.9561 - val_loss: 0.5725 - val_accuracy: 0.9060
# Epoch 44/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.4074 - accuracy: 0.9586 - val_loss: 0.5918 - val_accuracy: 0.9035
# Epoch 45/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.3996 - accuracy: 0.9587 - val_loss: 0.5948 - val_accuracy: 0.9012
# Epoch 46/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.3947 - accuracy: 0.9590 - val_loss: 0.5733 - val_accuracy: 0.9029
# Epoch 47/50
# 244/244 [==============================] - 28s 113ms/step - loss: 0.3840 - accuracy: 0.9599 - val_loss: 0.4916 - val_accuracy: 0.9227
# Epoch 48/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.4004 - accuracy: 0.9570 - val_loss: 0.8217 - val_accuracy: 0.8427
# Epoch 49/50
# 244/244 [==============================] - 28s 112ms/step - loss: 0.3892 - accuracy: 0.9621 - val_loss: 0.5924 - val_accuracy: 0.9021
# Epoch 50/50
# 244/244 [==============================] - 28s 111ms/step - loss: 0.3802 - accuracy: 0.9613 - val_loss: 0.8529 - val_accuracy: 0.8656
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history = np.load(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}512.history.npy', allow_pickle=True).item()

plot_history(history)

# %% [markdown]
# ## EVALUATION

# %%
aug_drop_reg_512_model = keras.models.load_model(MODEL_SAVE_DIR / SAVE_NAME / f'{SAVE_NAME}512.model.keras')
test_loss, test_acc = aug_drop_reg_512_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 82/82 [==============================] - 136s 2s/step - loss: 1.4098 - accuracy: 0.8160
# Test accuracy: 0.816

# %%
generate_classification_report(aug_drop_reg_512_model, test_dataset)
# Out:
# 82/82 [==============================] - 14s 173ms/step
#               precision    recall  f1-score   support
#
#            A       0.44      0.99      0.61       200
#           Â       0.90      0.98      0.94       200
#           Ă       0.95      0.95      0.95       200
#            B       0.95      0.83      0.89       200
#            C       0.87      1.00      0.93       200
#            D       0.84      0.97      0.90       200
#            E       0.98      0.71      0.83       200
#            F       0.83      0.86      0.85       200
#            G       0.92      0.98      0.95       200
#            H       0.92      0.95      0.93       200
#            I       0.93      0.88      0.90       200
#            K       0.96      0.73      0.83       200
#            L       0.86      0.92      0.89       200
#            M       0.54      0.97      0.70       200
#            N       0.83      0.07      0.14       200
#            O       0.70      1.00      0.82       200
#            P       0.79      0.99      0.88       200
#            Q       1.00      0.61      0.76       200
#            R       1.00      0.32      0.48       200
#            S       0.31      0.07      0.11       200
#            T       0.96      0.63      0.76       200
#            U       0.64      0.95      0.76       200
#            V       1.00      0.90      0.94       200
#            W       0.91      1.00      0.95       200
#            X       0.96      1.00      0.98       200
#            Y       0.99      0.93      0.96       200
#
#     accuracy                           0.82      5200
#    macro avg       0.85      0.82      0.79      5200
# weighted avg       0.85      0.82      0.79      5200

# %%
plot_confusion_matrix(aug_drop_reg_512_model, test_dataset)
# Out:
# 82/82 [==============================] - 17s 200ms/step
